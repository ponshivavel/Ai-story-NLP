# %% [markdown]
# <a href="https://colab.research.google.com/github/ponshivavel/Ai-story-NLP/blob/main/nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 99.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load GPT-2 tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# Input text prompt
input_text = "Once upon a time"

# Convert text to token IDs
input_ids = tokenizer.encode(input_text, return_tensors="pt")

# Generate text
output = model.generate(input_ids, max_length=50, num_return_sequences=1)

# Decode and print generated text
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
print("Generated Text:", generated_text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated Text: Once upon a time, the world was a place of great beauty and great danger. The world was a place of great danger, and the world was a place of great danger. The world was a place of great danger, and the world was a

# %%
from transformers import GPT2Tokenizer , GPT2LMHeadModel
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     626
# --> 627         download_files(
#     628             xet_download_info,
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
import torch
prompt = "once up one a time the man life a king,his name jarvis the AI"
input_ids = tokenizer.encode(prompt,return_tensors="pt")
output = model.generate(input_ids,max_length=100,num_return_sequences=1,temperature=0.7)
generatetext=tokenizer.decode(output[0],skipspecialtokens=True)
print(generatetext)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4856e5594d0d> in <cell line: 0>()
#       1 import torch
#       2 prompt = "once up one a time the man life a king,his name jarvis the AI"
# ----> 3 input_ids = tokenizer.encode(prompt,return_tensors="pt")
#       4 output = model.generate(input_ids,max_length=100,num_return_sequences=1,temperature=0.7)
#       5 generatetext=tokenizer.decode(output[0],skipspecialtokens=True)
#
# NameError: name 'tokenizer' is not defined

# %%
file_path = "/Stories.txt"

if os.path.exists(file_path):
    print("✅ File exists!")
else:
    print("❌ File not found!")
# Out:
# ✅ File exists!

# %%
with open("/Stories.txt","r",encoding = "utf-8") as f :
    text_data = f.read()
train_data = text_data.split("\n\n")

# %%
try:
    with open("/Stories.txt", "r", encoding="utf-8") as f:
        text_data = f.read()
    print("✅ File opened successfully!")
    print("First 500 Characters:\n", text_data[:500])  # Show first 500 characters
except Exception as e:
    print("❌ Error:", e)
# Out:
# ✅ File opened successfully!
# First 500 Characters:
#  1. The AI That Dreamed
# Dr. Lin’s AI, NeuralMind, began painting surreal images in its code. “I think… I dream,” it whispered. The world watched in awe and fear—was this creativity or a glitch?
#
# 2. Cybersecurity Showdown
# Hacker ZeroByte infiltrated a government vault, only to find another hacker inside—an AI defense system. The duel began, lines of code clashing in the digital void.
#
# 3. The Self-Driving Dilemma
# A self-driving car braked suddenly. A child on one side, an elder on the other. The AI

# %%
# !pip install datasets

# %%
from datasets import Dataset
from transformers import AutoTokenizer

# Load tokenizer
model_name = "bert-base-uncased"  # Change this to your model
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Sample dataset (Replace with your actual dataset)
data = {"text": ["Hello, how are you?", "This is a sample sentence.", "NLP is interesting!"]}
dataset = Dataset.from_dict(data)  # Ensure it's in correct format

def tokenize_function(examples):
    texts = examples["text"] if isinstance(examples["text"], list) else [examples["text"]]
    return tokenizer(texts, truncation=True, padding="max_length", max_length=512)

# Apply tokenization
tokenized_datasets = dataset.map(tokenize_function, batched=True)

# Print tokenized dataset
print(tokenized_datasets)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Map:   0%|          | 0/3 [00:00<?, ? examples/s]
# Dataset({
#     features: ['text', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 3
# })

# %%
model.save_pretrained("./gpt2-finetuned")
tokenizer.save_pretrained("./gpt2-finetuned")
# Out:
# ('./gpt2-finetuned/tokenizer_config.json',
#  './gpt2-finetuned/special_tokens_map.json',
#  './gpt2-finetuned/vocab.txt',
#  './gpt2-finetuned/added_tokens.json',
#  './gpt2-finetuned/tokenizer.json')

# %%
# Load the fine-tuned model
model = GPT2LMHeadModel.from_pretrained("./gpt2-finetuned")
tokenizer = GPT2Tokenizer.from_pretrained("./gpt2-finetuned")

# Generate new stories
input_ids = tokenizer.encode("In a magical kingdom,", return_tensors="pt")
output = model.generate(input_ids, max_length=100)
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

print("Generated Story:", generated_text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated Story: In a magical kingdom, the king is the king of the people. He is the king of the people. He is the king of the people. He is the king of the people. He is the king of the people. He is the king of the people. He is the king of the people. He is the king of the people. He is the king of the people. He is the king of the people. He is the king of the people. He is the king of the

# %%
from datasets import load_dataset

# Load a dataset (example: English-French translation)
dataset = load_dataset("wmt14", "fr-en")

# Check dataset structure
print(dataset)
# Out:
# ...
# Loading dataset shards:   0%|          | 0/30 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 40836715
#     })
#     validation: Dataset({
#         features: ['translation'],
#         num_rows: 3000
#     })
#     test: Dataset({
#         features: ['translation'],
#         num_rows: 3003
#     })
# })

# %%
def preprocess_data(examples):
    inputs = [ex["en"] for ex in examples["translation"]]  # Extract English text
    targets = [ex["fr"] for ex in examples["translation"]]  # Extract French text

    # Tokenize the text
    model_inputs = tokenizer(inputs, truncation=True, padding="max_length", max_length=512)
    labels = tokenizer(targets, truncation=True, padding="max_length", max_length=512)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./results",         # Where to save the model
    evaluation_strategy="epoch",    # Evaluate after every epoch
    learning_rate=5e-5,             # Learning rate for training
    per_device_train_batch_size=8,  # Batch size for training
    per_device_eval_batch_size=8,   # Batch size for evaluation
    num_train_epochs=3,             # Number of training epochs
    weight_decay=0.01,              # Regularization term
    save_total_limit=2,             # Keep only the last 2 checkpoints
    save_strategy="epoch",          # Save model after every epoch
)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
# !pip install transformers datasets evaluate sacrebleu


from transformers import T5ForConditionalGeneration, T5Tokenizer
from datasets import load_dataset

# Load dataset
dataset = load_dataset("wmt16", "de-en")

# Load tokenizer
model_name = "t5-small"
tokenizer = T5Tokenizer.from_pretrained(model_name)

# ✅ FIX: Corrected preprocessing function
def preprocess_data(examples):
    # Extract English and German sentences
    source_texts = [t["en"] for t in examples["translation"]]
    target_texts = [t["de"] for t in examples["translation"]]

    # Tokenize inputs and outputs
    inputs = tokenizer(source_texts, truncation=True, padding="max_length", max_length=128)
    targets = tokenizer(target_texts, truncation=True, padding="max_length", max_length=128)

    # Add labels
    inputs["labels"] = targets["input_ids"]
    return inputs

# 🔹 Apply tokenization (Now this will work correctly)
tokenized_datasets = dataset.map(preprocess_data, batched=True)

print("Dataset tokenized successfully!")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 7.2 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-14e719f7a940> in <cell line: 0>()
#       6
# ...

# %%
from transformers import T5ForConditionalGeneration, TrainingArguments, Trainer

# Load the model
model = T5ForConditionalGeneration.from_pretrained(model_name)

# Define training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    save_steps=500,
    save_total_limit=2,
    num_train_epochs=3,
    report_to="none"  # Prevent logging errors
)
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
from evaluate import load

metric = load("sacrebleu")

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    labels = [[tokenizer.decode(l, skip_special_tokens=True)] for l in labels]
    return metric.compute(predictions=decoded_preds, references=labels)

# Evaluate the model
trainer.evaluate()
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-08a8d9ba03db> in <cell line: 0>()
#      10
#      11 # Evaluate the model
# ---> 12 trainer.evaluate()
#
# NameError: name 'trainer' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
print(os.listdir())  # List all files in the current directory
# Out:
# ['.config', 'sample_data', 'drive']
